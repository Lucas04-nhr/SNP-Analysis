# %% [markdown]
# # Data Analysis for Threshold Finding
#
# ## Introduction
#
# The result conbines all the data in both Beijing and Guangzhou.
# ...
#
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ## Import data

# %%
data = pd.read_csv('../../data/plink/result/plink_anno_merged.csv')
data
# Out:
#             Chr      Start        End Ref Alt Func.refGene Gene.refGene  \
# 0             1  143232017  143232017   T   A   intergenic  NONE;LSP1P5
# 1             1  143264536  143264536   G   A   intergenic  NONE;LSP1P5
# 2             1  143264536  143264536   G   A   intergenic  NONE;LSP1P5
# 3             1  143267076  143267076   A   C   intergenic  NONE;LSP1P5
# 4             1  143267076  143267076   A   C   intergenic  NONE;LSP1P5
# ..          ...        ...        ...  ..  ..          ...          ...
# 281  KI270709.1       7687       7687   A   T   intergenic    NONE;NONE
# 282  KI270709.1       7687       7687   A   T   intergenic    NONE;NONE
# 283  KI270709.1       7687       7687   A   T   intergenic    NONE;NONE
# 284  KI270709.1       7687       7687   A   T   intergenic    NONE;NONE
# 285  KI270723.1      33831      33831   G   T   intergenic    NONE;NONE
#
#         GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  ...  \
# 0    dist=NONE;dist=167954                  .                .  ...
# 1    dist=NONE;dist=135435                  .                .  ...
# 2    dist=NONE;dist=135435                  .                .  ...
# 3    dist=NONE;dist=132895                  .                .  ...
# 4    dist=NONE;dist=132895                  .                .  ...
# ..                     ...                ...              ...  ...
# 281    dist=NONE;dist=NONE                  .                .  ...
# 282    dist=NONE;dist=NONE                  .                .  ...
# 283    dist=NONE;dist=NONE                  .                .  ...
# 284    dist=NONE;dist=NONE                  .                .  ...
# 285    dist=NONE;dist=NONE                  .                .  ...
#
#             CHR         UNADJ            GC          BONF          HOLM  \
# 0             1  8.965000e-12  8.965000e-12  7.539000e-07  7.535000e-07
# 1             1  9.850000e-04  3.390000e-03  1.000000e+00  1.000000e+00
# 2             1  1.336000e-03  5.273000e-03  1.000000e+00  1.000000e+00
# 3             1  5.677000e-04  2.045000e-03  1.000000e+00  1.000000e+00
# 4             1  8.844000e-04  2.630000e-03  1.000000e+00  1.000000e+00
# ..          ...           ...           ...           ...           ...
# 281  KI270709.1  1.998000e-04  1.165000e-03  1.000000e+00  1.000000e+00
# 282  KI270709.1  1.081000e-04  6.024000e-04  1.000000e+00  1.000000e+00
# 283  KI270709.1  7.821000e-04  3.496000e-03  1.000000e+00  1.000000e+00
# 284  KI270709.1  2.343000e-04  1.139000e-03  1.000000e+00  1.000000e+00
# 285  KI270723.1  4.466000e-04  1.470000e-03  1.000000e+00  1.000000e+00
#
#          SIDAK_SS      SIDAK_SD        FDR_BH        FDR_BY Cov
# 0    7.539000e-07  7.535000e-07  1.933000e-08  2.304000e-07   1
# 1    1.000000e+00  1.000000e+00  8.684000e-01  1.000000e+00  40
# 2    1.000000e+00  1.000000e+00  8.531000e-01  1.000000e+00  20
# 3    1.000000e+00  1.000000e+00  8.928000e-01  1.000000e+00  15
# 4    1.000000e+00  1.000000e+00  8.637000e-01  1.000000e+00   3
# ..            ...           ...           ...           ...  ..
# 281  1.000000e+00  1.000000e+00  6.222000e-01  1.000000e+00  14
# 282  9.999000e-01  9.999000e-01  4.410000e-01  1.000000e+00  33
# 283  1.000000e+00  1.000000e+00  8.529000e-01  1.000000e+00  25
# 284  1.000000e+00  1.000000e+00  7.579000e-01  1.000000e+00  27
# 285  1.000000e+00  1.000000e+00  5.778000e-01  1.000000e+00  35
#
# [286 rows x 36 columns]
